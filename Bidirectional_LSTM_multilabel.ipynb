# %% [markdown]
# # Configuration
# ____________________

# %%
# set main directories
BASE_DIR = '/content/gdrive/MyDrive/AML_project/project/'
UTILS_DIR = BASE_DIR + 'utils'
DATA_DIR = BASE_DIR + 'data/'
TOKENIZER_DIR = BASE_DIR + 'tokenizers/'
MODEL_DIR = BASE_DIR + 'models/'
PRED_DIR = BASE_DIR + 'predictions/'
# mount drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# set utils directory
import sys
sys.path.append(UTILS_DIR)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Imports
# ____________________

# %%
import numpy as np
from numpy.random import seed
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import nltk
import string
import re
import io
from tensorflow import keras, random
from tensorflow.keras import layers, regularizers, callbacks, metrics, initializers
from keras.layers import Embedding, Conv1D, Dense, Flatten, MaxPooling1D, Input, Concatenate, Flatten, Dropout, SpatialDropout1D, LSTM, GRU, Bidirectional, GlobalAvgPool1D, GlobalMaxPool1D
from keras.models import Model, load_model, save_model
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, average_precision_score, roc_auc_score, confusion_matrix, roc_curve, precision_recall_curve, auc, f1_score, precision_score, recall_score
from sklearn.metrics import multilabel_confusion_matrix
# custom imports
from utils import getComments, train_val_split
from preprocessing import Preprocessor
from embeddings import load_glove_vectors, load_fasttext_vectors
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Setup

# %%
### SETTINGS ###
settings = {
      'RANDOM_STATE': 42,
      'EMBEDDING_CHOICE': 'fasttext', # 'fasttext', 'glove'
      'SOURCES': ['de', 'fr', 'es'], # ['de', 'fr', 'es', 'syn_0', 'syn_1', 'syn_2'], use [] to keep only original data 
      'TEST_SIZE': 0.2,
      'UNDERSAMPLE': False
}
# set seeds
seed(settings['RANDOM_STATE'])
random.set_seed(settings['RANDOM_STATE'])
# shortcut
labels = ['toxic', 'severe_toxic',	'obscene',	'threat',	'insult',	'identity_hate']
targets = ['toxic', 'severe_toxic',	'obscene',	'threat',	'insult',	'identity_hate', 'is_toxic']

# %% [markdown]
# # Load data
# ____________________

# %%
# load train
if settings['UNDERSAMPLE']:
  train = pd.read_csv(DATA_DIR + 'train_aug_und_cleaned.csv', sep='\t')
else:
  train = pd.read_csv(DATA_DIR + 'train_aug_cleaned.csv', sep='\t')

# load test
test = pd.read_csv(DATA_DIR + 'test_cleaned.csv', sep='\t')

# load test labels
test_labels = pd.read_csv(DATA_DIR + 'test_labels_cleaned.csv', sep='\t')

# %% [markdown]
# # Prepare data for model inputs
# ____________________

# %% [markdown]
# ## Multilabel model

# %%
# instantiate Preprocessor object
p_2 = Preprocessor(path_to_tokenizer=TOKENIZER_DIR + 'base_tokenizer.pickle')
# change num_words for toxic tokenizer
p_2.getTokenizer().num_words = 20000

# %% [markdown]
# It is necessary that during the split between training set and validation set, the augmented data will be added to the same set of their original values to avoid overfitting.

# %%
# split in train and validation
X_train_2, X_val_2, y_train_2, y_val_2 = train_val_split(X = train[train['is_toxic']==1],
                                                          targets=targets,
                                                          val_size=settings['TEST_SIZE'],
                                                          random_state=settings['RANDOM_STATE'], 
                                                          sources=settings['SOURCES'])

y_train_2 = y_train_2[labels]
y_val_2 = y_val_2[labels]

y_test_2 = test_labels[test_labels['is_toxic']==1][labels]
X_test_2 = test.loc[y_test_2.index, 'comment_text']
# Out:
# Augmenting with de ...
# Augmenting with fr ...
# Augmenting with es ...

# %%
print('Training size:', len(X_train_2))
print('Validation size:', len(X_val_2))
print('Test size:', len(X_test_2))
print('Split ratio:', round(len(X_val_2)/len(X_train_2), 2))
# Out:
# Training size: 51876
# Validation size: 12972
# Test size: 6242
# Split ratio: 0.25

# %%
# fit tokenizer
p_2.fitTokenizer(X_train_2)
print('Vocabulary 2 size: ',p_2.getVocabularySize())
# Out:
# Vocabulary 2 size:  39488

# %%
# save fitted toxic tokenizer
p_2.saveTokenizer(TOKENIZER_DIR + 'fitted_multilabel_tokenizer_lstm')

# %%
# transform train, val and test comments to sequences
X_train_2 = p_2.toSequences(X_train_2)
X_val_2 = p_2.toSequences(X_val_2)
X_test_2 = p_2.toSequences(X_test_2)

# %%
# load embedding
if settings['EMBEDDING_CHOICE'] == 'glove':
  embeddings_2 = load_glove_vectors(DATA_DIR + 'glove/glove.twitter.27B.200d.txt', p_2.getTokenizer())
if settings['EMBEDDING_CHOICE'] == 'fasttext':
  embeddings_2 = load_fasttext_vectors(DATA_DIR + 'fasttext/crawl-300d-2M.vec', p_2.getTokenizer())

print('Embeddings 2 shape: ', embeddings_2.shape)
# Out:
# Loading FastText Model and building embedding matrix with vocabulary...
# DONE
# Embeddings 2 shape:  (39488, 300)

# %% [markdown]
# # utils

# %%
#import pickle
#with open(base_dir + 'history', 'wb') as file_pi:
#        pickle.dump(history.history, file_pi)
def saveWordIndexes(tokenizer):
  with open(base_dir + 'saved_model/word_index.json', 'w') as fp:
    json.dump(tokenizer.word_index, fp)

def plotHistory(history, metrics, title):
  plt.title(title)
  plt.plot(history.history[metrics[0]])
  plt.plot(history.history[metrics[1]])
  plt.ylabel(metrics[0])
  plt.xlabel('epoch')
  plt.legend(['train', 'validation'], loc='upper left')

def plot_roc(y_test, y_score):
  # plot settings
  lw = 2
  figure(figsize=(10,8))
  num_classes = 6
  y_test = np.array(y_test)
  # Compute ROC curve and ROC area for each class
  fpr = dict()
  tpr = dict()
  roc_auc = dict()
  for i in range(num_classes):
      fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])

  # First aggregate all false positive rates
  all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

  # Then interpolate all ROC curves at this points
  mean_tpr = np.zeros_like(all_fpr)
  for i in range(num_classes):
      mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

  # Finally average it and compute AUC
  mean_tpr /= num_classes

  fpr["macro"] = all_fpr
  tpr["macro"] = mean_tpr
  roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])


  # Plot all ROC curves
  plt.plot(fpr["macro"], tpr["macro"],
          label='macro-average ROC curve (area = {0:0.2f})'
                ''.format(roc_auc["macro"]),
          color='navy', linestyle=':', linewidth=4)

  colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
  for i, color in zip(range(num_classes), colors):
      plt.plot(fpr[i], tpr[i], color=color, lw=lw,
              label='ROC curve of class {0} (area = {1:0.2f})'
              ''.format(labels[i], roc_auc[i]))
  
  plt.plot([0, 1], [0, 1], 'k--', lw=lw)
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Multilabel ROC CURVE')
  plt.legend(loc="lower right")
  plt.show()

def print_confusion_matrix(y_true, y_pred):
  i = 0
  for cm in multilabel_confusion_matrix(y_true, y_pred, samplewise=False):
    print('###################')
    print(labels[i])
    print(cm)
    i = i+1

# %% [markdown]
# # Build model - Bidirectional LSTM
# ____________________

# %%
def BiLSTM(vocab_size, max_len, embedding, output_size):
  #### INITIALIZER
  initializer = initializers.GlorotUniform(seed=settings['RANDOM_STATE'])

  #### INPUT
  inputs = Input(shape=(max_len,))

  #### EMBEDDING LAYER
  embedding = Embedding(input_dim=vocab_size, output_dim=embedding.shape[1], weights=[embedding], input_length=max_len, trainable=False)(inputs)

  spatial = SpatialDropout1D(0.2)(embedding)
  
  #### LSTM LAYER
  bilstm = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3, kernel_initializer=initializer))(spatial)

  # pools after LSTM
  max_pool = GlobalMaxPool1D()(bilstm)
  avg_pool = GlobalAvgPool1D()(bilstm)

  # concatenate both pooling and use both info
  merged = Concatenate()([max_pool, avg_pool])

  #### FULLY CONNECTED LAYERS
  dense1 = Dense(64, activation='relu', kernel_initializer=initializer)(merged)
  dropout = Dropout(0.3)(dense1)

  outputs = Dense(output_size, activation='sigmoid')(dropout)

  # compile model
  model = Model(inputs=inputs, outputs=outputs)
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[metrics.Precision(), metrics.AUC(multi_label=True)])
  print(model.summary())
  return model

# %% [markdown]
# ## Create model - Multilabel classification
# ____________________

# %%
model_multi = BiLSTM(p_2.getVocabularySize(), p_2.getMaxLen(), embeddings_2, 6)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 150, 300)     11846400    input_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo (None, 150, 300)     0           embedding[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 150, 256)     439296      spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 256)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 256)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512)          0           global_max_pooling1d[0][0]
#                                                                  global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           32832       concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 6)            390         dropout[0][0]
# ==================================================================================================
# Total params: 12,318,918
# Trainable params: 472,518
# Non-trainable params: 11,846,400
# __________________________________________________________________________________________________
# None

# %%
plot_model(model_multi, show_shapes=True)

# %% [markdown]
# ### Train model

# %%
history_multi = model_multi.fit(X_train_2, y_train_2, batch_size=128, epochs=50,
                                callbacks=callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
                                validation_data=(X_val_2, y_val_2))
# Out:
# Epoch 1/50
# 406/406 [==============================] - 55s 111ms/step - loss: 0.3786 - precision: 0.8089 - auc: 0.6573 - val_loss: 0.2722 - val_precision: 0.8665 - val_auc: 0.8613
# Epoch 2/50
# 406/406 [==============================] - 43s 107ms/step - loss: 0.2889 - precision: 0.8578 - auc: 0.8264 - val_loss: 0.2594 - val_precision: 0.8702 - val_auc: 0.8816
# Epoch 3/50
# 406/406 [==============================] - 43s 107ms/step - loss: 0.2765 - precision: 0.8621 - auc: 0.8527 - val_loss: 0.2505 - val_precision: 0.8864 - val_auc: 0.8940
# Epoch 4/50
# 406/406 [==============================] - 43s 106ms/step - loss: 0.2658 - precision: 0.8651 - auc: 0.8667 - val_loss: 0.2449 - val_precision: 0.8496 - val_auc: 0.9051
# Epoch 5/50
# 406/406 [==============================] - 43s 106ms/step - loss: 0.2571 - precision: 0.8660 - auc: 0.8804 - val_loss: 0.2331 - val_precision: 0.8627 - val_auc: 0.9126
# Epoch 6/50
# 406/406 [==============================] - 43s 106ms/step - loss: 0.2503 - precision: 0.8700 - auc: 0.8874 - val_loss: 0.2246 - val_precision: 0.8582 - val_auc: 0.9216
# Epoch 7/50
# 406/406 [==============================] - 43s 106ms/step - loss: 0.2401 - precision: 0.8724 - auc: 0.8994 - val_loss: 0.2077 - val_precision: 0.8963 - val_auc: 0.9344
# Epoch 8/50
# 406/406 [==============================] - 43s 106ms/step - loss: 0.2319 - precision: 0.8753 - auc: 0.9064 - val_loss: 0.2001 - val_precision: 0.8737 - val_auc: 0.9391
# Epoch 9/50
# 406/406 [==============================] - 43s 107ms/step - loss: 0.2241 - precision: 0.8792 - auc: 0.9159 - val_loss: 0.1939 - val_precision: 0.8619 - val_auc: 0.9469
# Epoch 10/50
# 406/406 [==============================] - 43s 107ms/step - loss: 0.2151 - precision: 0.8818 - auc: 0.9239 - val_loss: 0.1772 - val_precision: 0.9062 - val_auc: 0.9544
# Epoch 11/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.2076 - precision: 0.8849 - auc: 0.9299 - val_loss: 0.1726 - val_precision: 0.8839 - val_auc: 0.9574
# Epoch 12/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.2023 - precision: 0.8885 - auc: 0.9337 - val_loss: 0.1674 - val_precision: 0.9054 - val_auc: 0.9607
# Epoch 13/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1952 - precision: 0.8933 - auc: 0.9386 - val_loss: 0.1557 - val_precision: 0.9020 - val_auc: 0.9650
# Epoch 14/50
# 406/406 [==============================] - 44s 107ms/step - loss: 0.1878 - precision: 0.8979 - auc: 0.9438 - val_loss: 0.1545 - val_precision: 0.8945 - val_auc: 0.9675
# Epoch 15/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1833 - precision: 0.8996 - auc: 0.9473 - val_loss: 0.1431 - val_precision: 0.9150 - val_auc: 0.9709
# Epoch 16/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1769 - precision: 0.9030 - auc: 0.9502 - val_loss: 0.1359 - val_precision: 0.9236 - val_auc: 0.9729
# Epoch 17/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1735 - precision: 0.9056 - auc: 0.9520 - val_loss: 0.1409 - val_precision: 0.9095 - val_auc: 0.9748
# Epoch 18/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1676 - precision: 0.9090 - auc: 0.9571 - val_loss: 0.1273 - val_precision: 0.9273 - val_auc: 0.9767
# Epoch 19/50
# 406/406 [==============================] - 44s 107ms/step - loss: 0.1637 - precision: 0.9112 - auc: 0.9587 - val_loss: 0.1231 - val_precision: 0.9242 - val_auc: 0.9776
# Epoch 20/50
# 406/406 [==============================] - 43s 107ms/step - loss: 0.1588 - precision: 0.9142 - auc: 0.9609 - val_loss: 0.1339 - val_precision: 0.8996 - val_auc: 0.9770
# Epoch 21/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1572 - precision: 0.9153 - auc: 0.9614 - val_loss: 0.1161 - val_precision: 0.9284 - val_auc: 0.9789
# Epoch 22/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1541 - precision: 0.9156 - auc: 0.9633 - val_loss: 0.1154 - val_precision: 0.9324 - val_auc: 0.9808
# Epoch 23/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1492 - precision: 0.9192 - auc: 0.9653 - val_loss: 0.1137 - val_precision: 0.9312 - val_auc: 0.9809
# Epoch 24/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1461 - precision: 0.9215 - auc: 0.9666 - val_loss: 0.1092 - val_precision: 0.9352 - val_auc: 0.9816
# Epoch 25/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1430 - precision: 0.9225 - auc: 0.9684 - val_loss: 0.1072 - val_precision: 0.9341 - val_auc: 0.9823
# Epoch 26/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1426 - precision: 0.9223 - auc: 0.9688 - val_loss: 0.1036 - val_precision: 0.9451 - val_auc: 0.9824
# Epoch 27/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1407 - precision: 0.9258 - auc: 0.9691 - val_loss: 0.1032 - val_precision: 0.9371 - val_auc: 0.9832
# Epoch 28/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1355 - precision: 0.9259 - auc: 0.9713 - val_loss: 0.0988 - val_precision: 0.9468 - val_auc: 0.9842
# Epoch 29/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1344 - precision: 0.9269 - auc: 0.9720 - val_loss: 0.0982 - val_precision: 0.9379 - val_auc: 0.9845
# Epoch 30/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1308 - precision: 0.9290 - auc: 0.9732 - val_loss: 0.0942 - val_precision: 0.9452 - val_auc: 0.9846
# Epoch 31/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1303 - precision: 0.9301 - auc: 0.9737 - val_loss: 0.0932 - val_precision: 0.9454 - val_auc: 0.9848
# Epoch 32/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1290 - precision: 0.9298 - auc: 0.9747 - val_loss: 0.0928 - val_precision: 0.9415 - val_auc: 0.9851
# Epoch 33/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1265 - precision: 0.9324 - auc: 0.9746 - val_loss: 0.0884 - val_precision: 0.9519 - val_auc: 0.9866
# Epoch 34/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1259 - precision: 0.9319 - auc: 0.9754 - val_loss: 0.0846 - val_precision: 0.9568 - val_auc: 0.9866
# Epoch 35/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1237 - precision: 0.9332 - auc: 0.9763 - val_loss: 0.0879 - val_precision: 0.9460 - val_auc: 0.9868
# Epoch 36/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1198 - precision: 0.9348 - auc: 0.9774 - val_loss: 0.0808 - val_precision: 0.9563 - val_auc: 0.9873
# Epoch 37/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1187 - precision: 0.9355 - auc: 0.9772 - val_loss: 0.0810 - val_precision: 0.9568 - val_auc: 0.9873
# Epoch 38/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1189 - precision: 0.9351 - auc: 0.9783 - val_loss: 0.0827 - val_precision: 0.9496 - val_auc: 0.9871
# Epoch 39/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1162 - precision: 0.9373 - auc: 0.9784 - val_loss: 0.0798 - val_precision: 0.9599 - val_auc: 0.9873
# Epoch 40/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1169 - precision: 0.9386 - auc: 0.9790 - val_loss: 0.0787 - val_precision: 0.9559 - val_auc: 0.9880
# Epoch 41/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1145 - precision: 0.9364 - auc: 0.9797 - val_loss: 0.0800 - val_precision: 0.9510 - val_auc: 0.9872
# Epoch 42/50
# 406/406 [==============================] - 44s 109ms/step - loss: 0.1131 - precision: 0.9388 - auc: 0.9794 - val_loss: 0.0822 - val_precision: 0.9457 - val_auc: 0.9875
# Epoch 43/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1126 - precision: 0.9379 - auc: 0.9794 - val_loss: 0.0775 - val_precision: 0.9552 - val_auc: 0.9876
# Epoch 44/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1106 - precision: 0.9389 - auc: 0.9804 - val_loss: 0.0806 - val_precision: 0.9465 - val_auc: 0.9875
# Epoch 45/50
# 406/406 [==============================] - 44s 109ms/step - loss: 0.1087 - precision: 0.9403 - auc: 0.9817 - val_loss: 0.0746 - val_precision: 0.9597 - val_auc: 0.9879
# Epoch 46/50
# 406/406 [==============================] - 44s 109ms/step - loss: 0.1074 - precision: 0.9422 - auc: 0.9816 - val_loss: 0.0730 - val_precision: 0.9569 - val_auc: 0.9890
# Epoch 47/50
# 406/406 [==============================] - 44s 108ms/step - loss: 0.1078 - precision: 0.9408 - auc: 0.9812 - val_loss: 0.0713 - val_precision: 0.9608 - val_auc: 0.9884
# Epoch 48/50
# 406/406 [==============================] - 44s 109ms/step - loss: 0.1061 - precision: 0.9422 - auc: 0.9816 - val_loss: 0.0775 - val_precision: 0.9529 - val_auc: 0.9893
# Epoch 49/50
# 406/406 [==============================] - 44s 109ms/step - loss: 0.1054 - precision: 0.9430 - auc: 0.9819 - val_loss: 0.0725 - val_precision: 0.9594 - val_auc: 0.9886
# Epoch 50/50
# 406/406 [==============================] - 44s 109ms/step - loss: 0.1034 - precision: 0.9443 - auc: 0.9833 - val_loss: 0.0713 - val_precision: 0.9580 - val_auc: 0.9897

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Plot learning curves

# %%
pd_history_multi = pd.DataFrame(history_multi.history)
pd_history_multi.plot(y=['loss', 'val_loss'])

# %% [markdown]
# Make predictions on the test set

# %%
y_score_multi = model_multi.predict(X_test_2)

# %% [markdown]
# Assign binary value to each label to compute accuracy

# %%
threshold = 0.5
y_pred_multi = [[1 if label >= threshold else 0 for label in score] for score in y_score_multi]

# %% [markdown]
# Measure the performance of the model

# %%
print('Accuracy (vector of labels must match):', round(accuracy_score(y_test_2, y_pred_multi), 5))
print('ROC AUC:', round(roc_auc_score(y_test_2, y_score_multi, average='macro'), 5))
print('Precision:', round(precision_score(y_test_2, y_pred_multi, average='macro'), 5))
print('Recall:', round(recall_score(y_test_2, y_pred_multi, average='macro'), 5))
print('F1 score:', round(f1_score(y_test_2, y_pred_multi, average='macro'), 5))
print(print_confusion_matrix(y_test_2, y_pred_multi))
# Out:
# Accuracy (vector of labels must match): 0.40452
# ROC AUC: 0.83001
# Precision: 0.64797
# Recall: 0.71318
# F1 score: 0.67289
# ###################
# toxic
# [[   8  145]
#  [ 129 5960]]
# ###################
# severe_toxic
# [[5353  522]
#  [ 168  199]]
# ###################
# obscene
# [[1582  970]
#  [ 556 3134]]
# ###################
# threat
# [[5935   96]
#  [  96  115]]
# ###################
# insult
# [[1779 1037]
#  [ 852 2574]]
# ###################
# identity_hate
# [[5256  274]
#  [ 276  436]]
# None

# %% [markdown]
# ## Save model and prediction

# %%
# save model
model_multi.save(MODEL_DIR + 'lstm_multi.h5', save_format='h5')
# save predictions
y_pred_multi = pd.DataFrame(y_pred_multi, columns=labels)
y_pred_multi.to_csv(PRED_DIR + 'lstm_multi.csv', index=False, sep='\t')
