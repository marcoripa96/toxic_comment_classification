# %% [markdown]
# # Configuration
# ____________________

# %%
# set main directories
BASE_DIR = '/content/gdrive/MyDrive/AML_project/project/'
UTILS_DIR = BASE_DIR + 'utils'
DATA_DIR = BASE_DIR + 'data/'
TOKENIZER_DIR = BASE_DIR + 'tokenizers/'
MODEL_DIR = BASE_DIR + 'models/'
PRED_DIR = BASE_DIR + 'predictions/'
# mount drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# set utils directory
import sys
sys.path.append(UTILS_DIR)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Imports
# ____________________

# %%
import numpy as np
from numpy.random import seed
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import pandas as pd
import nltk
import string
import re
import io
from tensorflow import keras, random
from tensorflow.keras import layers, regularizers, callbacks, metrics, initializers
from keras.layers import Embedding, Conv1D, Dense, Flatten, MaxPooling1D, Input, Concatenate, Flatten, Dropout, SpatialDropout1D, LSTM, GRU, Bidirectional, GlobalAvgPool1D, GlobalMaxPool1D
from keras.losses import BinaryCrossentropy
from keras.models import Model, load_model, save_model
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, average_precision_score, roc_auc_score, confusion_matrix, roc_curve, precision_recall_curve, auc, f1_score, precision_score, recall_score
from sklearn.metrics import multilabel_confusion_matrix
# custom imports
from utils import getComments, train_val_split
from preprocessing import Preprocessor
from embeddings import load_glove_vectors, load_fasttext_vectors
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Setup

# %%
### SETTINGS ###
settings = {
      'RANDOM_STATE': 42,
      'EMBEDDING_CHOICE': 'fasttext', # 'fasttext', 'glove'
      'SOURCES': ['de', 'fr', 'es'], # ['de', 'fr', 'es', 'syn_0', 'syn_1', 'syn_2'], use [] to keep only original data 
      'TEST_SIZE': 0.2,
      'UNDERSAMPLE': False
}
# set seeds
seed(settings['RANDOM_STATE'])
random.set_seed(settings['RANDOM_STATE'])
# shortcut
labels = ['toxic', 'severe_toxic',	'obscene',	'threat',	'insult',	'identity_hate']
targets = ['toxic', 'severe_toxic',	'obscene',	'threat',	'insult',	'identity_hate', 'is_toxic']

# %% [markdown]
# # Load data
# ____________________

# %%
# load train
if settings['UNDERSAMPLE']:
  train = pd.read_csv(DATA_DIR + 'train_aug_und_cleaned.csv', sep='\t')
else:
  train = pd.read_csv(DATA_DIR + 'train_aug_cleaned.csv', sep='\t')

# load test
test = pd.read_csv(DATA_DIR + 'test_cleaned.csv', sep='\t')

# load test labels
test_labels = pd.read_csv(DATA_DIR + 'test_labels_cleaned.csv', sep='\t')

# %% [markdown]
# # Prepare data for model inputs
# ____________________

# %% [markdown]
# ## Binary model

# %%
# instantiate Preprocessor object
p_1 = Preprocessor(path_to_tokenizer=TOKENIZER_DIR + 'base_tokenizer.pickle')

# %% [markdown]
# It is necessary that during the split between training set and validation set, the augmented data will be added to the same set of their original values to avoid overfitting.

# %%
# split in train and validation
X_train_1, X_val_1, y_train_1, y_val_1 = train_val_split(X = train,
                                                          targets=targets,
                                                          val_size=settings['TEST_SIZE'],
                                                          random_state=settings['RANDOM_STATE'], 
                                                          sources=settings['SOURCES'])

y_train_1 = y_train_1['is_toxic']
y_val_1 = y_val_1['is_toxic']
X_test_1 = test['comment_text'] 
y_test_1 = test_labels['is_toxic']
# Out:
# Augmenting with de ...
# Augmenting with fr ...
# Augmenting with es ...

# %%
print('Training size:', len(X_train_1))
print('Validation size:', len(X_val_1))
print('Test size:', len(X_test_1))
print('Split ratio:', round(len(X_val_1)/len(X_train_1), 2))
# Out:
# Training size: 166332
# Validation size: 41777
# Test size: 63517
# Split ratio: 0.25

# %%
# fit tokenizer
p_1.fitTokenizer(X_train_1)
print('Vocabulary 1 size: ',p_1.getVocabularySize())
# Out:
# Vocabulary 1 size:  146904

# %%
# save fitted binary tokenizer
p_1.saveTokenizer(TOKENIZER_DIR + 'fitted_binary_tokenizer_cnn')

# %%
# transform train, val and test comments to sequences
X_train_1 = p_1.toSequences(X_train_1)
X_val_1 = p_1.toSequences(X_val_1)
X_test_1 = p_1.toSequences(X_test_1)

# %%
# load embedding
if settings['EMBEDDING_CHOICE'] == 'glove':
  embeddings_1 = load_glove_vectors(DATA_DIR + 'glove/glove.twitter.27B.200d.txt', p_1.getTokenizer())
if settings['EMBEDDING_CHOICE'] == 'fasttext':
  embeddings_1 = load_fasttext_vectors(DATA_DIR + 'fasttext/crawl-300d-2M.vec', p_1.getTokenizer())

print('Embeddings 1 shape: ', embeddings_1.shape)
# Out:
# Loading FastText Model and building embedding matrix with vocabulary...
# DONE
# Embeddings 1 shape:  (146904, 300)

# %% [markdown]
# # utils

# %%
#import pickle
#with open(base_dir + 'history', 'wb') as file_pi:
#        pickle.dump(history.history, file_pi)
def saveWordIndexes(tokenizer):
  with open(base_dir + 'saved_model/word_index.json', 'w') as fp:
    json.dump(tokenizer.word_index, fp)

def plotHistory(history, metrics, title):
  plt.title(title)
  plt.plot(history.history[metrics[0]])
  plt.plot(history.history[metrics[1]])
  plt.ylabel(metrics[0])
  plt.xlabel('epoch')
  plt.legend(['train', 'validation'], loc='upper left')

def plot_roc(y_test, y_score):
  # plot settings
  lw = 2
  figure(figsize=(10,8))
  num_classes = 6
  y_test = np.array(y_test)
  # Compute ROC curve and ROC area for each class
  fpr = dict()
  tpr = dict()
  roc_auc = dict()
  for i in range(num_classes):
      fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
      roc_auc[i] = auc(fpr[i], tpr[i])

  # First aggregate all false positive rates
  all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

  # Then interpolate all ROC curves at this points
  mean_tpr = np.zeros_like(all_fpr)
  for i in range(num_classes):
      mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

  # Finally average it and compute AUC
  mean_tpr /= num_classes

  fpr["macro"] = all_fpr
  tpr["macro"] = mean_tpr
  roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])


  # Plot all ROC curves
  plt.plot(fpr["macro"], tpr["macro"],
          label='macro-average ROC curve (area = {0:0.2f})'
                ''.format(roc_auc["macro"]),
          color='navy', linestyle=':', linewidth=4)

  colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
  for i, color in zip(range(num_classes), colors):
      plt.plot(fpr[i], tpr[i], color=color, lw=lw,
              label='ROC curve of class {0} (area = {1:0.2f})'
              ''.format(labels[i], roc_auc[i]))
  
  plt.plot([0, 1], [0, 1], 'k--', lw=lw)
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Multilabel ROC CURVE')
  plt.legend(loc="lower right")
  plt.show()

def print_confusion_matrix(y_true, y_pred):
  i = 0
  for cm in multilabel_confusion_matrix(y_true, y_pred, samplewise=False):
    print('###################')
    print(labels[i])
    print(cm)
    i = i+1

# %% [markdown]
# # Build model - CNN multi
# ____________________

# %%
def CNNmulti(vocab_size, max_len, embedding, output_size, kernel_sizes = [4, 6, 8]):

  #### INITIALIZER
  initializer = initializers.GlorotUniform(seed=settings['RANDOM_STATE'])

  #### INPUT
  inputs = Input(shape=(max_len,))

  #### EMBEDDING LAYER
  embedding = Embedding(input_dim=vocab_size, output_dim=embedding.shape[1], weights=[embedding], input_length=max_len, trainable=False)(inputs)
  spatial = SpatialDropout1D(0.2)(embedding)

  #### CONVOLUTIONAL LAYERS
  # define first
  conv1 = Conv1D(32, kernel_sizes[0], activation='relu', kernel_initializer=initializer)(spatial)
  drop1 = Dropout(0.5)(conv1)
  pool1 = MaxPooling1D(2)(drop1)
  flat1 = Flatten()(pool1)

  # define second
  conv2 = Conv1D(32, kernel_sizes[1], activation='relu', kernel_initializer=initializer)(spatial)
  drop2 = Dropout(0.5)(conv2)
  pool2 = MaxPooling1D(2)(drop2)
  flat2 = Flatten()(pool2)

  # define third
  conv3 = Conv1D(32, kernel_sizes[2], activation='relu', kernel_initializer=initializer)(spatial)
  drop3 = Dropout(0.5)(conv3)
  pool3 = MaxPooling1D(2)(drop3)
  flat3 = Flatten()(pool3)

  # merge all
  merged = Concatenate()([flat1, flat2, flat3])

  #### FULLY CONNECTED LAYERS
  dense1 = Dense(64, activation='relu', kernel_initializer=initializer)(merged)
  outputs = Dense(output_size, activation='sigmoid')(dense1)

  # compile model
  model = Model(inputs=inputs, outputs=outputs)
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[metrics.Precision(), metrics.AUC(multi_label=True)])
  print(model.summary())
  return model

# %% [markdown]
# ## Create model - Binary classification
# ____________________

# %%
model_binary = CNNmulti(p_1.getVocabularySize(), p_1.getMaxLen(), embeddings_1, 1, [8,16,32])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 150)]        0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 150, 300)     44071200    input_3[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 150, 300)     0           embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 143, 32)      76832       spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 135, 32)      153632      spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 119, 32)      307232      spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 143, 32)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 135, 32)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 119, 32)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 71, 32)       0           dropout_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 67, 32)       0           dropout_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 59, 32)       0           dropout_8[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 2272)         0           max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 2144)         0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 1888)         0           max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6304)         0           flatten_6[0][0]
#                                                                  flatten_7[0][0]
#                                                                  flatten_8[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           403520      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            65          dense_4[0][0]
# ==================================================================================================
# Total params: 45,012,481
# Trainable params: 941,281
# Non-trainable params: 44,071,200
# __________________________________________________________________________________________________
# None

# %%
plot_model(model_binary, show_shapes=True)

# %% [markdown]
# ### Train model

# %%
history_binary = model_binary.fit(X_train_1, y_train_1, batch_size=256, epochs=20, 
                                  callbacks=callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
                                  validation_data=(X_val_1, y_val_1))
# Out:
# Epoch 1/20
# 650/650 [==============================] - 33s 38ms/step - loss: 0.3028 - precision_2: 0.8369 - auc_2: 0.9244 - val_loss: 0.1785 - val_precision_2: 0.8871 - val_auc_2: 0.9796
# Epoch 2/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1861 - precision_2: 0.8879 - auc_2: 0.9744 - val_loss: 0.1614 - val_precision_2: 0.8885 - val_auc_2: 0.9846
# Epoch 3/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1626 - precision_2: 0.9004 - auc_2: 0.9807 - val_loss: 0.1371 - val_precision_2: 0.9070 - val_auc_2: 0.9875
# Epoch 4/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1395 - precision_2: 0.9121 - auc_2: 0.9857 - val_loss: 0.1330 - val_precision_2: 0.8932 - val_auc_2: 0.9894
# Epoch 5/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1316 - precision_2: 0.9178 - auc_2: 0.9872 - val_loss: 0.1240 - val_precision_2: 0.9135 - val_auc_2: 0.9903
# Epoch 6/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1205 - precision_2: 0.9246 - auc_2: 0.9892 - val_loss: 0.1203 - val_precision_2: 0.9062 - val_auc_2: 0.9908
# Epoch 7/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1142 - precision_2: 0.9287 - auc_2: 0.9903 - val_loss: 0.1130 - val_precision_2: 0.9169 - val_auc_2: 0.9915
# Epoch 8/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1077 - precision_2: 0.9336 - auc_2: 0.9911 - val_loss: 0.1086 - val_precision_2: 0.9232 - val_auc_2: 0.9916
# Epoch 9/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1055 - precision_2: 0.9362 - auc_2: 0.9915 - val_loss: 0.1175 - val_precision_2: 0.8972 - val_auc_2: 0.9918
# Epoch 10/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.1002 - precision_2: 0.9363 - auc_2: 0.9924 - val_loss: 0.1053 - val_precision_2: 0.9159 - val_auc_2: 0.9920
# Epoch 11/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0951 - precision_2: 0.9397 - auc_2: 0.9931 - val_loss: 0.1097 - val_precision_2: 0.9082 - val_auc_2: 0.9926
# Epoch 12/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0908 - precision_2: 0.9445 - auc_2: 0.9936 - val_loss: 0.1077 - val_precision_2: 0.9108 - val_auc_2: 0.9924
# Epoch 13/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0876 - precision_2: 0.9476 - auc_2: 0.9941 - val_loss: 0.1039 - val_precision_2: 0.9203 - val_auc_2: 0.9924
# Epoch 14/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0850 - precision_2: 0.9480 - auc_2: 0.9943 - val_loss: 0.1001 - val_precision_2: 0.9255 - val_auc_2: 0.9926
# Epoch 15/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0824 - precision_2: 0.9524 - auc_2: 0.9948 - val_loss: 0.1051 - val_precision_2: 0.9140 - val_auc_2: 0.9927
# Epoch 16/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0804 - precision_2: 0.9508 - auc_2: 0.9949 - val_loss: 0.1012 - val_precision_2: 0.9243 - val_auc_2: 0.9926
# Epoch 17/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0799 - precision_2: 0.9521 - auc_2: 0.9951 - val_loss: 0.1025 - val_precision_2: 0.9168 - val_auc_2: 0.9928
# Epoch 18/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0774 - precision_2: 0.9532 - auc_2: 0.9953 - val_loss: 0.1091 - val_precision_2: 0.9080 - val_auc_2: 0.9924
# Epoch 19/20
# 650/650 [==============================] - 24s 37ms/step - loss: 0.0745 - precision_2: 0.9543 - auc_2: 0.9956 - val_loss: 0.1025 - val_precision_2: 0.9178 - val_auc_2: 0.9930

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Plot learning curves

# %%
pd_history_binary = pd.DataFrame(history_binary.history)
pd_history_binary.plot(y=['loss', 'val_loss'])

# %% [markdown]
# Make predictions on the test set

# %%
y_scores_binary = model_binary.predict(X_test_1)

# %% [markdown]
# Assign binary value to each label to compute accuracy

# %%
threshold = 0.5
y_pred_binary = [[1 if label >= threshold else 0 for label in score] for score in y_scores_binary]

# %% [markdown]
# Measure the performance of the model

# %%
print('Accuracy (vector of labels must match):', round(accuracy_score(y_test_1, y_pred_binary), 5))
print('ROC AUC:', round(roc_auc_score(y_test_1, y_scores_binary, average='macro'), 5))
print('Precision:', round(precision_score(y_test_1, y_pred_binary, average='macro'), 5))
print('Recall:', round(recall_score(y_test_1, y_pred_binary, average='macro'), 5))
print('F1 score:', round(f1_score(y_test_1, y_pred_binary, average='macro'), 5))
print(confusion_matrix(y_test_1, y_pred_binary))
# Out:
# Accuracy (vector of labels must match): 0.87499
# ROC AUC: 0.95983
# Precision: 0.71311
# Recall: 0.89636
# F1 score: 0.75911
# [[49816  7459]
#  [  481  5761]]

# %% [markdown]
# ## Save model and prediction

# %%
# save model
model_binary.save(MODEL_DIR + 'cnn_bin.h5', save_format='h5')
# save predictions
y_pred_binary = pd.DataFrame(y_pred_binary, columns=['is_toxic'])
y_pred_binary.to_csv(PRED_DIR + 'cnn_bin.csv', index=False, sep='\t')
